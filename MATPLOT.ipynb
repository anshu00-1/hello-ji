# %%
! pip install pandas
! pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_json("iris.json")

# %%
pd.read_json("iris.json")
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([11, 81])
ypoints = np.array([9, 20])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array([41, 24, 63, 85])
ypoints = np.array([3, 83, 15, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(xpoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'D')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "*:r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "*--r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "*-r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "*-.r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,"*-.r",ms=20,mec="k",mfc="b")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls = ':',lw=2 )
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls = '-.',lw=2 )
plt.show()

# %%
xpoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, color = 'r')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,color="r")
plt.plot(y,color="y")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,color="r")
plt.plot(y,color="y")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis="x")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,color="r")
plt.plot(y,color="y")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis="y")
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

#plot 3:
x = np.array([0, 1, 2, 3])
y = np.array([1, 20, 0, 40])

plt.subplot(2, 2, 3)
plt.plot(x,y)

#plot 4:
x = np.array([0, 1, 2, 3])
y = np.array([10, 2, 30, 0])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)
plt.colorbar()
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
colors = np.array(["red","green","blue","yellow"])
plt.barh(x, y, height = 0.1,color=colors)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.hist(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
colors=["r","k","b","y"]

plt.legend(title = "Four Fruits:")
plt.pie(y, labels= mylabels, explode = myexplode, shadow = True,colors=colors)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25220\1018399963.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title = "Four Fruits:")

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Optional import with newer Matplotlib versions

# Create a figure with specified size
fig = plt.figure(figsize=(12, 8))

# Add a 3D subplot
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D surface
p = ax.plot_surface(xx, yy, z, cmap='viridis')  # Replace xx, yy, and z with your data

# Add a color bar to indicate the scale of values
fig.colorbar(p, ax=ax)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 11
#       8 ax = fig.add_subplot(111, projection='3d')
#      10 # Plot the 3D surface
# ---> 11 p = ax.plot_surface(xx, yy, z, cmap='viridis')  # Replace xx, yy, and z with your data
#      13 # Add a color bar to indicate the scale of values
#      14 fig.colorbar(p, ax=ax)
#
# NameError: name 'xx' is not defined
